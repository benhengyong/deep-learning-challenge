# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns =['EIN','NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T9','T13','T12','T2','T25','T14','T29','T15','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts()>1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
v = application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts()< 1000]
v.index
# Out:
# Index(['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100',
#        'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000',
#        'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278',
#        'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600',
#        'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256',
#        'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820',
#        'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570',
#        'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561',
#        'C4500', 'C2150'],
#       dtype='object', name='CLASSIFICATION')

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100',
       'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000',
       'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278',
       'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600',
       'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256',
       'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820',
       'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570',
       'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561',
       'C4500', 'C2150']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop(columns = ['IS_SUCCESSFUL'])
y = application_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="sigmoid"))

#Add third hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=30, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:From C:\Users\benhe\anaconda3\envs\dev\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 30)                930
#
#  dense_3 (Dense)             (None, 1)                 31
#
# ...
# Total params: 6911 (27.00 KB)
# Trainable params: 6911 (27.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From C:\Users\benhe\anaconda3\envs\dev\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\benhe\anaconda3\envs\dev\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\benhe\anaconda3\envs\dev\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5871 - accuracy: 0.7137
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5570 - accuracy: 0.7305
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5539 - accuracy: 0.7325
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5519 - accuracy: 0.7322
# Epoch 5/100
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5555 - accuracy: 0.7242 - 1s/epoch - 4ms/step
# Loss: 0.5554747581481934, Accuracy: 0.7241982221603394

# %%
# Improvement test 1 using auto-optimisation to find the most accurate neural network model
# Results: the range of hidden layers from 1 to 6, alongside a max limit of 100 nodes per layer with a
#          max epoch of 100 led to incomplete testing. The entire testing process ran for 3 hours 
#          before shutting down due to running out of memory and not finding a result that improved
#          the 75% accuracy

# %%
 # !pip install keras-tuner

# %%
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=100,
        step=2), activation=activation, input_dim=43))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=100,
            step=2),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=100,
    hyperband_iterations=2)
# Out:
# Reloading Tuner from .\untitled_project\tuner0.json

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=100,validation_data=(X_test_scaled,y_test))

# %%
#Improvement test 2: Doubling the number of nodes at every hidden layer
#Results: Loss: 0.5616635680198669, Accuracy: 0.7253644466400146
#         When compared to the accuracy value of 0.72419, there was a small improvement accuracy of 
#          approx 0.0012, however is not significant change to reach 75%

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=160, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

#Add third hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 160)               7040
#
#  dense_4 (Dense)             (None, 60)                9660
#
#  dense_5 (Dense)             (None, 60)                3660
#
#  dense_6 (Dense)             (None, 1)                 61
#
# ...
# Total params: 20421 (79.77 KB)
# Trainable params: 20421 (79.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 1ms/step - loss: 0.5755 - accuracy: 0.7191
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5566 - accuracy: 0.7304
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5537 - accuracy: 0.7311
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5530 - accuracy: 0.7312
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5511 - accuracy: 0.7315
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5500 - accuracy: 0.7336
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5491 - accuracy: 0.7345
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5481 - accuracy: 0.7334
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5476 - accuracy: 0.7344
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5617 - accuracy: 0.7254 - 506ms/epoch - 2ms/step
# Loss: 0.5616635680198669, Accuracy: 0.7253644466400146

# %%
#Improvement test 3: Double the number of hidden layers alongisde the previous doubling of nodes
# Results: only 0.0006 difference between test 2 and test 3

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=160, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

#Add third hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

#Add fourth hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

#Add fifth hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

#Add sixth hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 160)               7040
#
#  dense_8 (Dense)             (None, 60)                9660
#
#  dense_9 (Dense)             (None, 60)                3660
#
#  dense_10 (Dense)            (None, 60)                3660
#
#  dense_11 (Dense)            (None, 60)                3660
#
#  dense_12 (Dense)            (None, 60)                3660
#
#  dense_13 (Dense)            (None, 1)                 61
#
# ...
# Total params: 31401 (122.66 KB)
# Trainable params: 31401 (122.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 2ms/step - loss: 0.5947 - accuracy: 0.7072
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5678 - accuracy: 0.7285
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5578 - accuracy: 0.7313
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5555 - accuracy: 0.7320
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5532 - accuracy: 0.7337
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5513 - accuracy: 0.7331
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5516 - accuracy: 0.7346
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5500 - accuracy: 0.7329
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5491 - accuracy: 0.7343
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5585 - accuracy: 0.7259 - 1s/epoch - 4ms/step
# Loss: 0.558544397354126, Accuracy: 0.7259474992752075

# %%
# Out:
# RangeIndex(start=0, stop=34299, step=1)

# %%
#improvement test 4: Drop columns status, income_amt and special considerations
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df = application_df.drop(columns = ['EIN','NAME','STATUS','INCOME_AMT','SPECIAL_CONSIDERATIONS'])

# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T9','T13','T12','T2','T25','T14','T29','T15','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100',
       'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000',
       'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278',
       'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600',
       'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256',
       'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820',
       'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570',
       'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561',
       'C4500', 'C2150']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
application_df
# Out:
#         ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0          5000              1                   False                  True
# 1        108590              1                   False                 False
# 2          5000              0                   False                 False
# 3          6692              1                   False                 False
# 4        142590              1                   False                 False
# ...         ...            ...                     ...                   ...
# 34294      5000              0                   False                 False
# 34295      5000              0                   False                 False
# 34296      5000              0                   False                 False
# 34297      5000              1                   False                 False
# 34298  36500179              0                   False                 False
#
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop(columns = ['IS_SUCCESSFUL'])
y = application_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=160, activation="relu", input_dim=31))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

#Add third hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

#Add fourth hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

#Add fifth hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

#Add sixth hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=60, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 160)               5120
#
#  dense_22 (Dense)            (None, 60)                9660
#
#  dense_23 (Dense)            (None, 60)                3660
#
#  dense_24 (Dense)            (None, 60)                3660
#
#  dense_25 (Dense)            (None, 60)                3660
#
#  dense_26 (Dense)            (None, 60)                3660
#
#  dense_27 (Dense)            (None, 1)                 61
#
# ...
# Total params: 29481 (115.16 KB)
# Trainable params: 29481 (115.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\benhe\anaconda3\envs\dev\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\benhe\anaconda3\envs\dev\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 804/804 [==============================] - 2s 1ms/step - loss: 0.6023 - accuracy: 0.6964
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5754 - accuracy: 0.7242
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5669 - accuracy: 0.7256
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5654 - accuracy: 0.7282
# Epoch 5/100
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5556 - accuracy: 0.7291 - 509ms/epoch - 2ms/step
# Loss: 0.555586576461792, Accuracy: 0.7290962338447571

# %%
#Test 5
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=160, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="sigmoid"))

#Add third hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=10, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_36 (Dense)            (None, 160)               7040
#
#  dense_37 (Dense)            (None, 30)                4830
#
#  dense_38 (Dense)            (None, 10)                310
#
#  dense_39 (Dense)            (None, 1)                 11
#
# ...
# Total params: 12191 (47.62 KB)
# Trainable params: 12191 (47.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6009 - accuracy: 0.7010
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5704 - accuracy: 0.7310
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5617 - accuracy: 0.7318
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5561 - accuracy: 0.7327
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5532 - accuracy: 0.7329
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5517 - accuracy: 0.7342
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7343
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5492 - accuracy: 0.7350
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5487 - accuracy: 0.7336
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5563 - accuracy: 0.7238 - 390ms/epoch - 1ms/step
# Loss: 0.5563271641731262, Accuracy: 0.7238484025001526

# %%
#Test 6 Add NAME Column Back into dataframe and Group Outliers into OTHER and adjust the bin value for 
# to increase the number of categories in classifications by 3
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df = application_df.drop(columns = ['EIN'])

application_df['NAME'].value_counts()[application_df['NAME'].value_counts()< 150]
# Out:
# NAME
# VETERANS OF FOREIGN WARS OF THE UNITED STATES AUXILIARY                 144
# PTA UTAH CONGRESS                                                       140
# THE UNITED STATES PONY CLUBS INC                                        136
# CIVITAN INTERNATIONAL                                                   131
# SIGMA BETA DELTA INC                                                    127
#                                                                        ...
# ST LOUIS SLAM WOMENS FOOTBALL                                             1
# AIESEC ALUMNI IBEROAMERICA CORP                                           1
# WEALLBLEEDRED ORG INC                                                     1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI      1
# WATERHOUSE CHARITABLE TR                                                  1
# Name: count, Length: 19549, dtype: int64

# %%
test = application_df['NAME'].value_counts()[application_df['NAME'].value_counts()< 150].index
test.values
# Out:
# array(['VETERANS OF FOREIGN WARS OF THE UNITED STATES AUXILIARY',
#        'PTA UTAH CONGRESS', 'THE UNITED STATES PONY CLUBS INC', ...,
#        'WEALLBLEEDRED ORG INC',
#        'AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI',
#        'WATERHOUSE CHARITABLE TR'], dtype=object)

# %%
names_to_replace = test.values
for name in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(name,"Other")

# %%
application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                                                 27297
# PARENT BOOSTER USA INC                                                 1260
# TOPS CLUB INC                                                           765
# UNITED STATES BOWLING CONGRESS INC                                      700
# WASHINGTON STATE UNIVERSITY                                             492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                         408
# PTA TEXAS CONGRESS                                                      368
# SOROPTIMIST INTERNATIONAL OF THE AMERICAS INC                           331
# ALPHA PHI SIGMA                                                         313
# TOASTMASTERS INTERNATIONAL                                              293
# MOST WORSHIPFUL STRINGER FREE AND ACCEPTED MASONS                       287
# LITTLE LEAGUE BASEBALL INC                                              277
# ...

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T9','T13','T12','T2','T25','T14','T29','T15','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C5000', 'C1270', 'C2700', 'C2800', 'C7100',
       'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000',
       'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278',
       'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600',
       'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256',
       'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820',
       'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570',
       'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561',
       'C4500', 'C2150']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
application_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  NAME_ALPHA PHI SIGMA  \
# 0           1      5000              1                 False
# 1           1    108590              1                 False
# 2           1      5000              0                 False
# 3           1      6692              1                 False
# 4           1    142590              1                 False
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                 False
# 34295       1      5000              0                 False
# 34296       1      5000              0                 False
# 34297       1      5000              1                 False
# 34298       1  36500179              0                 False
#
#        NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC  \
# 0                                                  False
# 1                                                  False
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop(columns = ['IS_SUCCESSFUL'])
y = application_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=160, activation="relu", input_dim=66))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="sigmoid"))

#Add third hidden layer to increase accuracy
nn.add(tf.keras.layers.Dense(units=10, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_56 (Dense)            (None, 160)               10720
#
#  dense_57 (Dense)            (None, 30)                4830
#
#  dense_58 (Dense)            (None, 10)                310
#
#  dense_59 (Dense)            (None, 1)                 11
#
# ...
# Total params: 15871 (62.00 KB)
# Trainable params: 15871 (62.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5541 - accuracy: 0.7325
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5155 - accuracy: 0.7526
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5073 - accuracy: 0.7549
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5041 - accuracy: 0.7556
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5020 - accuracy: 0.7563
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.4990 - accuracy: 0.7568
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.4980 - accuracy: 0.7586
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.4972 - accuracy: 0.7580
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.4957 - accuracy: 0.7584
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5172 - accuracy: 0.7499 - 288ms/epoch - 1ms/step
# Loss: 0.5171756148338318, Accuracy: 0.7498542070388794
